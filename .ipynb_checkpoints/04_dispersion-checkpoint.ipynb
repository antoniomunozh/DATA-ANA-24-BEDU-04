# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
# Crear un diccionario con los datos de nivel de estrés y horas de sueño.
data = {
    'Nivel_de_estres': [7, 6, 8, 5, 9, 4, 7, 3, 10, 2,11],
    'Horas_de_sueño': [5, 6, 4, 7, 3, 8, 5, 9, 2, 10,8]
}

# Crear un DataFrame con los datos.
df = pd.DataFrame(data)

# Mostrar el DataFrame.
df.head()
# Out:
#    Nivel_de_estres  Horas_de_sueño
# 0                7               5
# 1                6               6
# 2                8               4
# 3                5               7
# 4                9               3

# %%
plt.scatter(
    df['Nivel_de_estres'],
    df['Horas_de_sueño']
)

# %% [markdown]
# ### Personalización

# %%
plt.scatter(
    df['Nivel_de_estres'],
    df['Horas_de_sueño']
)
plt.title('Relación entre el nivel de extres y horas de sueño')
plt.xlabel('Nivel de estres')
plt.ylabel('Horas de sueño')
plt.grid(True)
plt.show()
